# %% [markdown]
# <a href="https://colab.research.google.com/github/Vicente-VP/Analise_Premier2324/blob/main/PremierLeague.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data_team = pd.read_csv("season-2324.csv")

# %%
data_team.head()
# Out:
#        Date     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  11/08/23      Burnley       Man City     0     3   A     0     2   A
# 1  12/08/23      Arsenal  Nott'm Forest     2     1   H     2     0   H
# 2  12/08/23  Bournemouth       West Ham     1     1   D     0     0   D
# 3  12/08/23     Brighton          Luton     4     1   H     1     0   H
# 4  12/08/23      Everton         Fulham     0     1   A     0     0   D
#
#      Referee  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0   C Pawson  ...    1    8  11   8   6   5   0   0   1   0
# 1   M Oliver  ...    7    2  12  12   8   3   2   2   0   0
# 2   P Bankes  ...    5    3   9  14  10   4   1   4   0   0
# 3    D Coote  ...   12    3  11  12   6   7   2   2   0   0
# 4  S Attwell  ...    9    2  12   6  10   4   0   2   0   0
#
# [5 rows x 22 columns]

# %%
data_team.columns=["Data", "Casa", "Fora", "Gols_marcadosCasa", "Gols_marcadosFora", "Resultado", "Gols_1_Casa", "Gols_1_Fora", "Resultado_1", "Arbitro", "Chutes_Casa", "Chutes_Fora", "ChutesAlvo_Casa", "ChutesAlvo_Fora", "Faltas_Casa", "Faltas_Fora", "Escanteio_Casa", "Escanteio_Fora", "Amarelo_Casa", "Amarelo_Fora", "Vermelho_Casa", "Vermelho_Fora"]

# %%
data_team.query("Casa == 'Man City'")
# Out:
#          Data      Casa              Fora  Gols_marcadosCasa  \
# 15   19/08/23  Man City         Newcastle                  1
# 34   02/09/23  Man City            Fulham                  5
# 51   23/09/23  Man City     Nott'm Forest                  2
# 83   21/10/23  Man City          Brighton                  2
# 104  04/11/23  Man City       Bournemouth                  6
# 120  25/11/23  Man City         Liverpool                  1
# 139  03/12/23  Man City         Tottenham                  3
# 162  16/12/23  Man City    Crystal Palace                  2
# 191  30/12/23  Man City  Sheffield United                  2
# 213  31/01/24  Man City           Burnley                  3
# 228  10/02/24  Man City           Everton                  2
# 244  17/02/24  Man City           Chelsea                  1
# 248  20/02/24  Man City         Brentford                  1
# 266  03/03/24  Man City        Man United                  3
# 292  31/03/24  Man City           Arsenal                  0
# 300  03/04/24  Man City       Aston Villa                  4
# 316  13/04/24  Man City             Luton                  5
# 352  04/05/24  Man City            Wolves                  5
# 378  19/05/24  Man City          West Ham                  3
#
#      Gols_marcadosFora Resultado  Gols_1_Casa  Gols_1_Fora Resultado_1  \
# 15                   0         H            1            0           H
# 34                   1         H            2            1           H
# 51                   0         H            2            0           H
# 83                   1         H            2            0           H
# 104                  1         H            3            0           H
# 120                  1         D            1            0           H
# 139                  3         D            2            1           H
# 162                  2         D            1            0           H
# 191                  0         H            1            0           H
# 213                  1         H            2            0           H
# 228                  0         H            0            0           D
# 244                  1         D            0            1           A
# 248                  0         H            0            0           D
# 266                  1         H            0            1           A
# 292                  0         D            0            0           D
# 300                  1         H            2            1           H
# 316                  1         H            1            0           H
# 352                  1         H            3            0           H
# 378                  1         H            2            1           H
#
#         Arbitro  ...  ChutesAlvo_Casa  ChutesAlvo_Fora  Faltas_Casa  \
# 15      R Jones  ...                4                1           12
# 34     M Oliver  ...                5                4           12
# 51     A Taylor  ...                4                3            5
# 83      R Jones  ...                6                3            9
# 104    C Pawson  ...                8                1            8
# 120  C Kavanagh  ...                5                3            9
# 139    S Hooper  ...                4                4           14
# 162   P Tierney  ...                9                2           12
# 191     D Coote  ...                4                2            5
# 213   S Barrott  ...                4                3            3
# 228    J Brooks  ...                3                1            6
# 244    A Madley  ...                5                6            7
# 248   D England  ...               11                2           12
# 266    A Madley  ...                8                1            5
# 292    A Taylor  ...                1                2            9
# 300   D England  ...               11                3            6
# 316    J Brooks  ...               13                2            7
# 352    C Pawson  ...               12                1            4
# 378    J Brooks  ...               12                2            3
#
#      Faltas_Fora  Escanteio_Casa  Escanteio_Fora  Amarelo_Casa  Amarelo_Fora  \
# 15            11               3               0             1             5
# 34            12               4               5             2             4
# 51            17               6               6             3             7
# 83            11               2               2             2             2
# 104            9              12               1             0             1
# 120           11               9               6             1             3
# 139           14              10               8             4             4
# 162            9               6               1             1             1
# 191            6              12               2             1             1
# 213           13               7               3             2             2
# 228           11               9               0             0             2
# 244           12              12               1             1             3
# 248            6              10               1             2             4
# 266           10              15               2             0             1
# 292           20               7               4             0             2
# 300           13               2               3             1             2
# 316            6              12               1             1             0
# 352           17               6               0             0             4
# 378           12              11               2             0             1
#
#      Vermelho_Casa  Vermelho_Fora
# 15               0              0
# 34               0              0
# 51               1              0
# 83               1              0
# 104              0              0
# 120              0              0
# 139              0              0
# 162              0              0
# 191              0              0
# 213              0              0
# 228              0              0
# 244              0              0
# 248              0              0
# 266              0              0
# 292              0              0
# 300              0              0
# 316              0              0
# 352              0              0
# 378              0              0
#
# [19 rows x 22 columns]

# %%
data_team.head()
# Out:
#        Data         Casa           Fora  Gols_marcadosCasa  Gols_marcadosFora  \
# 0  11/08/23      Burnley       Man City                  0                  3
# 1  12/08/23      Arsenal  Nott'm Forest                  2                  1
# 2  12/08/23  Bournemouth       West Ham                  1                  1
# 3  12/08/23     Brighton          Luton                  4                  1
# 4  12/08/23      Everton         Fulham                  0                  1
#
#   Resultado  Gols_1_Casa  Gols_1_Fora Resultado_1    Arbitro  ...  \
# 0         A            0            2           A   C Pawson  ...
# 1         H            2            0           H   M Oliver  ...
# 2         D            0            0           D   P Bankes  ...
# 3         H            1            0           H    D Coote  ...
# 4         A            0            0           D  S Attwell  ...
#
#    ChutesAlvo_Casa  ChutesAlvo_Fora  Faltas_Casa  Faltas_Fora  Escanteio_Casa  \
# 0                1                8           11            8               6
# 1                7                2           12           12               8
# 2                5                3            9           14              10
# 3               12                3           11           12               6
# 4                9                2           12            6              10
#
#    Escanteio_Fora  Amarelo_Casa  Amarelo_Fora  Vermelho_Casa  Vermelho_Fora
# 0               5             0             0              1              0
# 1               3             2             2              0              0
# 2               4             1             4              0              0
# 3               7             2             2              0              0
# 4               4             0             2              0              0
#
# [5 rows x 22 columns]

# %%
total_jogos_ganhos = data_team.query("(Resultado == 'H') & (Casa == 'Burnley')").Resultado.value_counts()['H']
total_jogos_perdidos = data_team.query("(Resultado == 'A') & (Casa == 'Burnley')").Resultado.value_counts()['A']
total_jogos_empatados = data_team.query("(Resultado == 'D') & (Casa == 'Burnley')").Resultado.value_counts()['D']
print(total_jogos_ganhos, total_jogos_perdidos)
# Out:
# 2 13

# %%
dados = {
    "Desempenho": ["Vitórias", "Derrotas", "Empates"],
    "Total": [total_jogos_ganhos,total_jogos_perdidos, total_jogos_empatados],
}

dados = pd.DataFrame(dados, index = ["Vitoria", "Derrota", "Empate"])
dados = dados.sort_values(by="Total")

# %%
dados
# Out:
#         Desempenho  Total
# Vitoria   Vitórias      2
# Empate     Empates      4
# Derrota   Derrotas     13

# %%
dados.plot.bar(x="Desempenho", y="Total", rot = 45)
# Out:
# <Axes: xlabel='Desempenho'>

# %%
dados.plot.pie(y="Total", figsize=(5, 5))
# Out:
# <Axes: ylabel='Total'>

# %%
data_team.head()
# Out:
#        Data         Casa           Fora  Gols_marcadosCasa  Gols_marcadosFora  \
# 0  11/08/23      Burnley       Man City                  0                  3
# 1  12/08/23      Arsenal  Nott'm Forest                  2                  1
# 2  12/08/23  Bournemouth       West Ham                  1                  1
# 3  12/08/23     Brighton          Luton                  4                  1
# 4  12/08/23      Everton         Fulham                  0                  1
#
#   Resultado  Gols_1_Casa  Gols_1_Fora Resultado_1    Arbitro  ...  \
# 0         A            0            2           A   C Pawson  ...
# 1         H            2            0           H   M Oliver  ...
# 2         D            0            0           D   P Bankes  ...
# 3         H            1            0           H    D Coote  ...
# 4         A            0            0           D  S Attwell  ...
#
#    ChutesAlvo_Casa  ChutesAlvo_Fora  Faltas_Casa  Faltas_Fora  Escanteio_Casa  \
# 0                1                8           11            8               6
# 1                7                2           12           12               8
# 2                5                3            9           14              10
# 3               12                3           11           12               6
# 4                9                2           12            6              10
#
#    Escanteio_Fora  Amarelo_Casa  Amarelo_Fora  Vermelho_Casa  Vermelho_Fora
# 0               5             0             0              1              0
# 1               3             2             2              0              0
# 2               4             1             4              0              0
# 3               7             2             2              0              0
# 4               4             0             2              0              0
#
# [5 rows x 22 columns]

# %%
# Supondo que sua coluna 'Data' é no formato "dd/mm/yy"
data_team['Data'] = pd.to_datetime(data_team['Data'], format='%d/%m/%y')

# Adiciona uma coluna 'Mes' ao DataFrame
data_team['Mes'] = data_team['Data'].dt.month

# Filtrando jogos para um mês específico (exemplo: Agosto = 8)
jogos_agosto = data_team.query("Mes == 8")
jogos_agosto
# Out:
#          Data              Casa              Fora  Gols_marcadosCasa  \
# 0  2023-08-11           Burnley          Man City                  0
# 1  2023-08-12           Arsenal     Nott'm Forest                  2
# 2  2023-08-12       Bournemouth          West Ham                  1
# 3  2023-08-12          Brighton             Luton                  4
# 4  2023-08-12           Everton            Fulham                  0
# 5  2023-08-12  Sheffield United    Crystal Palace                  0
# 6  2023-08-12         Newcastle       Aston Villa                  5
# 7  2023-08-13         Brentford         Tottenham                  2
# 8  2023-08-13           Chelsea         Liverpool                  1
# 9  2023-08-14        Man United            Wolves                  1
# 10 2023-08-18     Nott'm Forest  Sheffield United                  2
# 11 2023-08-19            Fulham         Brentford                  0
# 12 2023-08-19         Liverpool       Bournemouth                  3
# 13 2023-08-19            Wolves          Brighton                  1
# 14 2023-08-19         Tottenham        Man United                  2
# 15 2023-08-19          Man City         Newcastle                  1
# 16 2023-08-20       Aston Villa           Everton                  4
# 17 2023-08-20          West Ham           Chelsea                  3
# 18 2023-08-21    Crystal Palace           Arsenal                  0
# 19 2023-08-25           Chelsea             Luton                  3
# 20 2023-08-26       Bournemouth         Tottenham                  0
# 21 2023-08-26           Arsenal            Fulham                  2
# 22 2023-08-26         Brentford    Crystal Palace                  1
# 23 2023-08-26           Everton            Wolves                  0
# 24 2023-08-26        Man United     Nott'm Forest                  3
# 25 2023-08-26          Brighton          West Ham                  1
# 26 2023-08-27           Burnley       Aston Villa                  1
# 27 2023-08-27  Sheffield United          Man City                  1
# 28 2023-08-27         Newcastle         Liverpool                  1
#
#     Gols_marcadosFora Resultado  Gols_1_Casa  Gols_1_Fora Resultado_1  \
# 0                   3         A            0            2           A
# 1                   1         H            2            0           H
# 2                   1         D            0            0           D
# 3                   1         H            1            0           H
# 4                   1         A            0            0           D
# 5                   1         A            0            0           D
# 6                   1         H            2            1           H
# 7                   2         D            2            2           D
# 8                   1         D            1            1           D
# 9                   0         H            0            0           D
# 10                  1         H            1            0           H
# 11                  3         A            0            1           A
# 12                  1         H            2            1           H
# 13                  4         A            0            1           A
# 14                  0         H            0            0           D
# 15                  0         H            1            0           H
# 16                  0         H            2            0           H
# 17                  1         H            1            1           D
# 18                  1         A            0            0           D
# 19                  0         H            1            0           H
# 20                  2         A            0            1           A
# 21                  2         D            0            1           A
# 22                  1         D            1            0           H
# 23                  1         A            0            0           D
# 24                  2         H            1            2           A
# 25                  3         A            0            1           A
# 26                  3         A            0            2           A
# 27                  2         A            0            0           D
# 28                  2         A            1            0           H
#
#         Arbitro  ...  ChutesAlvo_Fora  Faltas_Casa  Faltas_Fora  \
# 0      C Pawson  ...                8           11            8
# 1      M Oliver  ...                2           12           12
# 2      P Bankes  ...                3            9           14
# 3       D Coote  ...                3           11           12
# 4     S Attwell  ...                2           12            6
# 5      J Brooks  ...                8           18           11
# 6      A Madley  ...                6           12           17
# 7       R Jones  ...                6           12           13
# 8      A Taylor  ...                1            5           12
# 9      S Hooper  ...                6           14           10
# 10     P Bankes  ...                3            5            9
# 11       D Bond  ...                8           13           12
# 12    T Bramall  ...                5           11           13
# 13     A Madley  ...                8           14           11
# 14     M Oliver  ...                6            9            8
# 15      R Jones  ...                1           12           11
# 16     A Taylor  ...                2            8           12
# 17     J Brooks  ...                4           12            9
# 18      D Coote  ...                3           14           10
# 19      R Jones  ...                1           15           12
# 20   T Robinson  ...                6           18           11
# 21    P Tierney  ...                3            6            5
# 22     P Bankes  ...                5            9           15
# 23     C Pawson  ...                2           10           14
# 24    S Attwell  ...                4           13           11
# 25     A Taylor  ...                3           10            9
# 26  M Salisbury  ...                6           12           11
# 27    J Gillett  ...                9           11            2
# 28     J Brooks  ...                4           16           10
#
#     Escanteio_Casa  Escanteio_Fora  Amarelo_Casa  Amarelo_Fora  Vermelho_Casa  \
# 0                6               5             0             0              1
# 1                8               3             2             2              0
# 2               10               4             1             4              0
# 3                6               7             2             2              0
# 4               10               4             0             2              0
# 5                5               5             3             0              0
# 6                6               5             4             4              0
# 7                3               6             1             4              0
# 8                4               4             3             3              0
# 9                8               7             2             3              0
# 10               6               7             2             3              0
# 11               5               5             2             2              1
# 12              10               2             1             3              1
# 13               5               3             3             6              1
# 14               5               6             1             3              0
# 15               3               0             1             5              0
# 16               7               6             3             4              0
# 17               3               9             2             3              1
# 18               1               8             2             1              0
# 19               6               4             2             3              0
# 20               6               2             1             3              0
# 21               8               3             0             3              0
# 22               8               6             0             0              0
# 23               7               0             3             4              0
# 24              11               3             4             4              0
# 25              17               4             1             3              0
# 26               4               6             2             0              0
# 27               1              12             3             0              0
# 28               5               9             1             2              0
#
#     Vermelho_Fora  Mes
# 0               0    8
# 1               0    8
# 2               0    8
# 3               0    8
# 4               0    8
# 5               0    8
# 6               0    8
# 7               0    8
# 8               0    8
# 9               0    8
# 10              0    8
# 11              0    8
# 12              0    8
# 13              0    8
# 14              0    8
# 15              0    8
# 16              0    8
# 17              0    8
# 18              1    8
# 19              0    8
# 20              0    8
# 21              1    8
# 22              0    8
# 23              0    8
# 24              1    8
# 25              0    8
# 26              0    8
# 27              0    8
# 28              1    8
#
# [29 rows x 23 columns]

# %%
meses = {
    "Janeiro": data_team.query("(Mes == 1) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Fevereiro": data_team.query("(Mes == 2) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Março": data_team.query("(Mes == 3) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Abril": data_team.query("(Mes == 4) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Maio": data_team.query("(Mes == 5) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Junho": data_team.query("(Mes == 6) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Julho": data_team.query("(Mes == 7) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Agosto": data_team.query("(Mes == 8) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Setembro": data_team.query("(Mes == 9) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Outubro": data_team.query("(Mes == 10) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Novembro": data_team.query("(Mes == 11) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
    "Dezembro": data_team.query("(Mes == 12) & (Casa == 'Burnley')")['Resultado'].value_counts().get("A", 0),
}

df_meses = pd.DataFrame(list(meses.items()), columns=['Mês', 'Derrotas'])
df_meses
# Out:
#           Mês  Derrotas
# 0     Janeiro         0
# 1   Fevereiro         1
# 2       Março         1
# 3       Abril         0
# 4        Maio         2
# 5       Junho         0
# 6       Julho         0
# 7      Agosto         2
# 8    Setembro         2
# 9     Outubro         1
# 10   Novembro         2
# 11   Dezembro         2

# %%
df_meses.plot.bar(x='Mês', y='Derrotas')
# Out:
# <Axes: xlabel='Mês'>

# %%
data_team.head()
# Out:
#         Data         Casa           Fora  Gols_marcadosCasa  \
# 0 2023-08-11      Burnley       Man City                  0
# 1 2023-08-12      Arsenal  Nott'm Forest                  2
# 2 2023-08-12  Bournemouth       West Ham                  1
# 3 2023-08-12     Brighton          Luton                  4
# 4 2023-08-12      Everton         Fulham                  0
#
#    Gols_marcadosFora Resultado  Gols_1_Casa  Gols_1_Fora Resultado_1  \
# 0                  3         A            0            2           A
# 1                  1         H            2            0           H
# 2                  1         D            0            0           D
# 3                  1         H            1            0           H
# 4                  1         A            0            0           D
#
#      Arbitro  ...  ChutesAlvo_Fora  Faltas_Casa  Faltas_Fora  Escanteio_Casa  \
# 0   C Pawson  ...                8           11            8               6
# 1   M Oliver  ...                2           12           12               8
# 2   P Bankes  ...                3            9           14              10
# 3    D Coote  ...                3           11           12               6
# 4  S Attwell  ...                2           12            6              10
#
#    Escanteio_Fora  Amarelo_Casa  Amarelo_Fora  Vermelho_Casa  Vermelho_Fora  \
# 0               5             0             0              1              0
# 1               3             2             2              0              0
# 2               4             1             4              0              0
# 3               7             2             2              0              0
# 4               4             0             2              0              0
#
#    Mes
# 0    8
# 1    8
# 2    8
# 3    8
# 4    8
#
# [5 rows x 23 columns]

# %%
gols_totais_1 = data_team["Gols_1_Casa"].sum()
gols_totais = data_team['Gols_marcadosCasa'].sum()
gols_2_tempo = gols_totais - gols_totais_1
print(gols_2_tempo)
# Out:
# 405

# %%
comparacao = {
    'tempos': ['1º Tempo', '2º Tempo'],
    'gols': [gols_totais_1, gols_2_tempo]
}

comparacao = pd.DataFrame(comparacao)
comparacao
# Out:
#      tempos  gols
# 0  1º Tempo   279
# 1  2º Tempo   405

# %%
comparacao.plot.bar(x='tempos', y='gols')
# Out:
# <Axes: xlabel='tempos'>

# %%
data_team.ChutesAlvo_Fora.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_team.head()
# Out:
#         Data         Casa           Fora  Gols_marcadosCasa  \
# 0 2023-08-11      Burnley       Man City                  0
# 1 2023-08-12      Arsenal  Nott'm Forest                  2
# 2 2023-08-12  Bournemouth       West Ham                  1
# 3 2023-08-12     Brighton          Luton                  4
# 4 2023-08-12      Everton         Fulham                  0
#
#    Gols_marcadosFora Resultado  Gols_1_Casa  Gols_1_Fora Resultado_1  \
# 0                  3         A            0            2           A
# 1                  1         H            2            0           H
# 2                  1         D            0            0           D
# 3                  1         H            1            0           H
# 4                  1         A            0            0           D
#
#      Arbitro  ...  ChutesAlvo_Fora  Faltas_Casa  Faltas_Fora  Escanteio_Casa  \
# 0   C Pawson  ...                8           11            8               6
# 1   M Oliver  ...                2           12           12               8
# 2   P Bankes  ...                3            9           14              10
# 3    D Coote  ...                3           11           12               6
# 4  S Attwell  ...                2           12            6              10
#
#    Escanteio_Fora  Amarelo_Casa  Amarelo_Fora  Vermelho_Casa  Vermelho_Fora  \
# 0               5             0             0              1              0
# 1               3             2             2              0              0
# 2               4             1             4              0              0
# 3               7             2             2              0              0
# 4               4             0             2              0              0
#
#    Mes
# 0    8
# 1    8
# 2    8
# 3    8
# 4    8
#
# [5 rows x 23 columns]

# %%
city_gol_1_casa = data_team.query("Casa == 'Man City'")["Gols_1_Casa"].sum()
city_gol_1_fora = data_team.query("Fora == 'Man City'")["Gols_1_Fora"].sum()
city_1 = city_gol_1_casa + city_gol_1_fora
print(city_1)
# Out:
# 40

# %%
city_gol_casa = data_team.query("Casa == 'Man City'")["Gols_marcadosCasa"].sum()
city_gol_fora = data_team.query("Fora == 'Man City'")["Gols_marcadosFora"].sum()
city_gols = city_gol_casa + city_gol_fora
print(city_gols)
# Out:
# 96

# %%
gol_2 = city_gols - city_1
print(gol_2)
# Out:
# 56

# %%
gols_city= {
    "tempos": ["1º Tempo", "2º Tempo"],
    "gols": [city_1, gol_2]
}

gols_city = pd.DataFrame(gols_city)
gols_city
# Out:
#      tempos  gols
# 0  1º Tempo    40
# 1  2º Tempo    56

# %%
gols_city.plot.bar(x="tempos", y="gols", title="Gols do Man City nos Tempos do jogo")
# Out:
# <Axes: title={'center': 'Gols do Man City nos Tempos do jogo'}, xlabel='tempos'>

# %%
data_team.head()
gols = data_team.query("Fora == 'Burnley'")["Gols_1_Fora"].sum() + data_team.query("Casa == 'Burnley'")["Gols_1_Casa"].sum()
print(gols)
# Out:
# 18

# %%
gols_por_time = {}
gols_1_por_time = {}
gols_2_por_time = {}

for i in data_team.index:
    time_casa = data_team.loc[i, "Casa"]
    gols_casa = data_team.loc[i, "Gols_marcadosCasa"]
    time_fora = data_team.loc[i, "Fora"]
    gols_fora = data_team.loc[i, "Gols_marcadosFora"]


    time_Casa_1 = data_team.loc[i, "Casa"]
    gols_Casa_1 = data_team.loc[i, "Gols_1_Casa"]
    time_fora_1 = data_team.loc[i, "Fora"]
    gols_fora_1 = data_team.loc[i, "Gols_1_Fora"]

    if time_casa in gols_por_time:
        gols_por_time[time_casa] += gols_casa
    else:
        gols_por_time[time_casa] = gols_casa

    if time_fora in gols_por_time:
        gols_por_time[time_fora] += gols_fora
    else:
        gols_por_time[time_fora] = gols_fora

    if time_Casa_1 in gols_1_por_time:
        gols_1_por_time[time_Casa_1] += gols_Casa_1
    else:
        gols_1_por_time[time_Casa_1] = gols_Casa_1

    if time_fora_1 in gols_1_por_time:
        gols_1_por_time[time_fora_1] += gols_fora_1
    else:
        gols_1_por_time[time_fora_1] = gols_fora_1

for time in gols_por_time:
    if time in gols_1_por_time:
        gols_2_por_time[time] = gols_por_time[time] - gols_1_por_time[time]
    else:
        gols_2_por_time[time] = gols_por_time[time]

# %%
gols_series = pd.Series(gols_por_time)
gols_series = gols_series.sort_values(ascending=True)
gols_series.plot(kind='bar', title="Total de Gols por Time", ylabel="Total de Gols", xlabel="Times", color='skyblue', figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Total de Gols por Time'}, xlabel='Times', ylabel='Total de Gols'>

# %%
gols_df = pd.DataFrame({
    "Primeiro Tempo": gols_1_por_time,
    "Segundo Tempo": gols_2_por_time
})

gols_df.sort_values(by="Primeiro Tempo", ascending=True, inplace=True)

gols_df.plot.bar(figsize=(17, 6), color=['skyblue', 'lightgreen'], title="Gols por Time: 1º e 2º Tempo")
# Out:
# <Axes: title={'center': 'Gols por Time: 1º e 2º Tempo'}>

# %%
data_team.query("Casa == 'Man City'")
# Out:
#           Data      Casa              Fora  Gols_marcadosCasa  \
# 15  2023-08-19  Man City         Newcastle                  1
# 34  2023-09-02  Man City            Fulham                  5
# 51  2023-09-23  Man City     Nott'm Forest                  2
# 83  2023-10-21  Man City          Brighton                  2
# 104 2023-11-04  Man City       Bournemouth                  6
# 120 2023-11-25  Man City         Liverpool                  1
# 139 2023-12-03  Man City         Tottenham                  3
# 162 2023-12-16  Man City    Crystal Palace                  2
# 191 2023-12-30  Man City  Sheffield United                  2
# 213 2024-01-31  Man City           Burnley                  3
# 228 2024-02-10  Man City           Everton                  2
# 244 2024-02-17  Man City           Chelsea                  1
# 248 2024-02-20  Man City         Brentford                  1
# 266 2024-03-03  Man City        Man United                  3
# 292 2024-03-31  Man City           Arsenal                  0
# 300 2024-04-03  Man City       Aston Villa                  4
# 316 2024-04-13  Man City             Luton                  5
# 352 2024-05-04  Man City            Wolves                  5
# 378 2024-05-19  Man City          West Ham                  3
#
#      Gols_marcadosFora Resultado  Gols_1_Casa  Gols_1_Fora Resultado_1  \
# 15                   0         H            1            0           H
# 34                   1         H            2            1           H
# 51                   0         H            2            0           H
# 83                   1         H            2            0           H
# 104                  1         H            3            0           H
# 120                  1         D            1            0           H
# 139                  3         D            2            1           H
# 162                  2         D            1            0           H
# 191                  0         H            1            0           H
# 213                  1         H            2            0           H
# 228                  0         H            0            0           D
# 244                  1         D            0            1           A
# 248                  0         H            0            0           D
# 266                  1         H            0            1           A
# 292                  0         D            0            0           D
# 300                  1         H            2            1           H
# 316                  1         H            1            0           H
# 352                  1         H            3            0           H
# 378                  1         H            2            1           H
#
#         Arbitro  ...  ChutesAlvo_Fora  Faltas_Casa  Faltas_Fora  \
# 15      R Jones  ...                1           12           11
# 34     M Oliver  ...                4           12           12
# 51     A Taylor  ...                3            5           17
# 83      R Jones  ...                3            9           11
# 104    C Pawson  ...                1            8            9
# 120  C Kavanagh  ...                3            9           11
# 139    S Hooper  ...                4           14           14
# 162   P Tierney  ...                2           12            9
# 191     D Coote  ...                2            5            6
# 213   S Barrott  ...                3            3           13
# 228    J Brooks  ...                1            6           11
# 244    A Madley  ...                6            7           12
# 248   D England  ...                2           12            6
# 266    A Madley  ...                1            5           10
# 292    A Taylor  ...                2            9           20
# 300   D England  ...                3            6           13
# 316    J Brooks  ...                2            7            6
# 352    C Pawson  ...                1            4           17
# 378    J Brooks  ...                2            3           12
#
#      Escanteio_Casa  Escanteio_Fora  Amarelo_Casa  Amarelo_Fora  \
# 15                3               0             1             5
# 34                4               5             2             4
# 51                6               6             3             7
# 83                2               2             2             2
# 104              12               1             0             1
# 120               9               6             1             3
# 139              10               8             4             4
# 162               6               1             1             1
# 191              12               2             1             1
# 213               7               3             2             2
# 228               9               0             0             2
# 244              12               1             1             3
# 248              10               1             2             4
# 266              15               2             0             1
# 292               7               4             0             2
# 300               2               3             1             2
# 316              12               1             1             0
# 352               6               0             0             4
# 378              11               2             0             1
#
#      Vermelho_Casa  Vermelho_Fora  Mes
# 15               0              0    8
# 34               0              0    9
# 51               1              0    9
# 83               1              0   10
# 104              0              0   11
# 120              0              0   11
# 139              0              0   12
# 162              0              0   12
# 191              0              0   12
# 213              0              0    1
# 228              0              0    2
# 244              0              0    2
# 248              0              0    2
# 266              0              0    3
# 292              0              0    3
# 300              0              0    4
# 316              0              0    4
# 352              0              0    5
# 378              0              0    5
#
# [19 rows x 23 columns]

# %%
desempenho = {}

for i in data_team.index:
    times = data_team.loc[i, "Casa"]
    resultado = data_team.loc[i, "Resultado"]

    if times in desempenho:
        if resultado == "H":
            desempenho[times]["vitória"] += 1
        elif resultado == "A":
            desempenho[times]["derrota"] += 1
        else:
            desempenho[times]["empate"] += 1
    else:
        desempenho[times] = {"vitória": 0, "empate": 0, "derrota": 0}

desempenho
# Out:
# {'Burnley': {'vitória': 2, 'empate': 4, 'derrota': 12},
#  'Arsenal': {'vitória': 14, 'empate': 2, 'derrota': 2},
#  'Bournemouth': {'vitória': 7, 'empate': 5, 'derrota': 6},
#  'Brighton': {'vitória': 7, 'empate': 6, 'derrota': 5},
#  'Everton': {'vitória': 8, 'empate': 4, 'derrota': 6},
#  'Sheffield United': {'vitória': 2, 'empate': 4, 'derrota': 12},
#  'Newcastle': {'vitória': 11, 'empate': 4, 'derrota': 3},
#  'Brentford': {'vitória': 5, 'empate': 6, 'derrota': 7},
#  'Chelsea': {'vitória': 11, 'empate': 3, 'derrota': 4},
#  'Man United': {'vitória': 9, 'empate': 3, 'derrota': 6},
#  "Nott'm Forest": {'vitória': 4, 'empate': 5, 'derrota': 9},
#  'Fulham': {'vitória': 9, 'empate': 2, 'derrota': 7},
#  'Liverpool': {'vitória': 14, 'empate': 3, 'derrota': 1},
#  'Wolves': {'vitória': 8, 'empate': 3, 'derrota': 7},
#  'Tottenham': {'vitória': 12, 'empate': 0, 'derrota': 6},
#  'Man City': {'vitória': 13, 'empate': 5, 'derrota': 0},
#  'Aston Villa': {'vitória': 11, 'empate': 4, 'derrota': 3},
#  'West Ham': {'vitória': 6, 'empate': 8, 'derrota': 4},
#  'Crystal Palace': {'vitória': 8, 'empate': 4, 'derrota': 6},
#  'Luton': {'vitória': 4, 'empate': 4, 'derrota': 10}}

# %%
df_desempenho = pd.DataFrame.from_dict(desempenho, orient="index")

df_desempenho.index.name = "Time"

df_desempenho.plot(kind="barh", figsize=(10, 20), title="Desempenho dos Times em Casa", ylabel="Quantidade", xlabel="Time", palette = "")
# Out:
# <Axes: title={'center': 'Desempenho dos Times em Casa'}, xlabel='Time', ylabel='Quantidade'>

# %%
df_desempenho
# Out:
#                   vitória  empate  derrota
# Time
# Burnley                 2       4       12
# Arsenal                14       2        2
# Bournemouth             7       5        6
# Brighton                7       6        5
# Everton                 8       4        6
# Sheffield United        2       4       12
# Newcastle              11       4        3
# Brentford               5       6        7
# Chelsea                11       3        4
# Man United              9       3        6
# Nott'm Forest           4       5        9
# Fulham                  9       2        7
# Liverpool              14       3        1
# Wolves                  8       3        7
# Tottenham              12       0        6
# Man City               13       5        0
# Aston Villa            11       4        3
# West Ham                6       8        4
# Crystal Palace          8       4        6
# Luton                   4       4       10
